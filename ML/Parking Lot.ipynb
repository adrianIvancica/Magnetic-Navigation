# %% [markdown]
# ### Data Set Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Use data collected on a ground floor, outdoor parking lot at a +/- 2 Gauss resolution on 4/14/24
parkingLot = pd.read_csv("magMapCaptureParkingLot2G_4_14_24.txt", sep=',')
parkingLot.head()
# Out:
#      X   Y     Z  Azimuth  Bearing Direction   Latitude  Longitude  Altitude  \
# 0  673  78  2489        6        0         N  25.713854 -80.283981       9.0
# 1  687  76  2485        6        0         N  25.713854 -80.283981       9.0
# 2  675  72  2477        6        0         N  25.713854 -80.283981       9.0
# 3  682  73  2497        6        0         N  25.713854 -80.283981       9.0
# 4  688  72  2507        5        0         N  25.713854 -80.283981       9.0
#
#          Date      Time
# 0  04/15/2024  00:49:15
# 1  04/15/2024  00:49:15
# 2  04/15/2024  00:49:16
# 3  04/15/2024  00:49:16
# 4  04/15/2024  00:49:16

# %%
# convert text file data into modifyable types compatible with pandas data structures

# convert string data to numeric data
col = ['X','Y','Z','Azimuth','Bearing','Latitude','Longitude','Altitude']
parkingLot[col] = parkingLot[col].apply(pd.to_numeric)
# convert date string to date object
col = ['Date']
parkingLot[col] = parkingLot[col].apply(lambda x: pd.to_datetime(x, format='%m/%d/%Y'))
# convert time string to time object
col = ['Time']
parkingLot[col] = parkingLot[col].apply(lambda x: pd.to_datetime(x, format='%H:%M:%S').dt.time)

# %%
# Functions used to convert raw digital data to nano Tesla
def convert_raw_to_mG(x, mode):
    if mode == 1: # assumes 2G/12000LSB ~ 0.167mG/LSB resolution
        return 2/12000 * x
    else: # assumes 8G/3000LSB ~ 2.67mG/LSB resolution
        return 8/3000 * x
def convert_mG_to_nT(x):
    return 100 * x
def convert_raw_to_nT(x, mode):
    mg = convert_raw_to_mG(x, mode)
    return convert_mG_to_nT(mg)

# %%
# convert raw data to nT
col = ['X','Y','Z']
parkingLot[col] = parkingLot[col].apply(lambda x: round(convert_raw_to_nT(x, 1),3))
parkingLot.head()
# Out:
#         X      Y       Z  Azimuth  Bearing Direction   Latitude  Longitude  \
# 0  11.217  1.300  41.483        6        0         N  25.713854 -80.283981
# 1  11.450  1.267  41.417        6        0         N  25.713854 -80.283981
# 2  11.250  1.200  41.283        6        0         N  25.713854 -80.283981
# 3  11.367  1.217  41.617        6        0         N  25.713854 -80.283981
# 4  11.467  1.200  41.783        5        0         N  25.713854 -80.283981
#
#    Altitude       Date      Time
# 0       9.0 2024-04-15  00:49:15
# 1       9.0 2024-04-15  00:49:15
# 2       9.0 2024-04-15  00:49:16
# 3       9.0 2024-04-15  00:49:16
# 4       9.0 2024-04-15  00:49:16

# %%
# Orientation: X = North, Y = East, Z = Straight Down
filter = (parkingLot['Direction'] == 'N') | (parkingLot['Direction'] == 'NNE') | (parkingLot['Direction'] == 'NNW')

# Latitude and Longitude (targets)
y = parkingLot.loc[filter, ['Longitude','Latitude']].values 

# X, Y, Z magnetic readings (features)
X = parkingLot.loc[filter, ['X','Y','Z']].values

# %% [markdown]
# ### Data Split Creation

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Scaled
XSS = StandardScaler()
XSS.fit(X)
X_scaled = XSS.transform(X)

ySS = StandardScaler()
ySS.fit(y)
y_scaled = ySS.transform(y)

# Normalized
XMMS = MinMaxScaler()
X_norm = XMMS.fit_transform(X)

yMMS = MinMaxScaler()
y_norm = yMMS.fit_transform(y)

# %%
# Standard Split
# Split data into a training set (70%) and a testing set (30%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1)

# Scaled Split
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(
    X_scaled, y_scaled, test_size=0.3, random_state=1)

# Normalized Split
X_train_norm, X_test_norm, y_train_norm, y_test_norm = train_test_split(
    X_norm, y_norm, test_size=0.3, random_state=1)

# %% [markdown]
# ### Defining Metrics

# %%
from sklearn.metrics import  mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

def metrics(test, pred):
    mse = mean_squared_error(test, pred)
    print(f'Mean Squared Error: {mse:.3f}')
    
    mae = mean_absolute_error(test, pred)
    print(f'Mean Absolute Error: {mae:.3f}')
    
    r2 = r2_score(test, pred)
    print(f'R2 Score: {r2:.3f}')
    
    evs = explained_variance_score(test, pred)
    print(f'Explained Variance Score: {evs:.3f}')

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# Define parameter grid
param_grid = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
    'max_depth': range(3, 11),
    'min_samples_leaf': range(3, 11)
}

# Create DecisionTreeRegressor instance
tree = DecisionTreeRegressor(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=tree, param_grid=param_grid, cv=10, n_jobs=-1, verbose=1)

# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 10 folds for each of 192 candidates, totalling 1920 fits
# Best Parameters: {'criterion': 'friedman_mse', 'max_depth': 7, 'min_samples_leaf': 10}
# Best Score: 0.13766502473723874

# %%
best_tree = DecisionTreeRegressor(criterion=best_params.get('criterion'),
                                         max_depth=best_params.get('max_depth'),
                                         min_samples_leaf=best_params.get('min_samples_leaf'),
                                         random_state=42)
best_tree.fit(X_train, y_train)
y_pred = best_tree.predict(X_test)
metrics(y_test, y_pred)
# Out:
# Mean Squared Error: 0.000
# Mean Absolute Error: 0.000
# R2 Score: 0.142
# Explained Variance Score: 0.142

# %%
plt.figure()
s = 25
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Decision Tree Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 150, 200],  # Number of trees in the forest
    'max_depth': range(1, 16),
    'min_samples_leaf': range(1, 6),
}

# Create RandomForestRegressor instance
rf_model = RandomForestRegressor(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=10, n_jobs=-1, verbose=1)

# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# Best Parameters: {'max_depth': 11, 'min_samples_leaf': 1, 'n_estimators': 150}
# Best Score: 0.22894923935302597

# %%
best_tree = RandomForestRegressor(n_estimators=best_params.get('n_estimators'),
                                         max_depth=best_params.get('max_depth'),
                                         min_samples_leaf=best_params.get('min_samples_leaf'),
                                         random_state=42)
best_tree.fit(X_train, y_train)
y_pred = best_tree.predict(X_test)
metrics(y_test, y_pred)
# Out:
# Mean Squared Error: 0.000
# Mean Absolute Error: 0.000
# R2 Score: 0.237
# Explained Variance Score: 0.237

# %%
plt.figure()
s = 25
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Random Forest Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Multi-Output Support Vector Regression

# %%
# MSVR needs data to be in the range -1 to 1 (normalized) in order to function properly
import sys
sys.path.append('./msvr-master/msvr-master')
from model.MSVR import MSVR
from model.utility import rmse
from sklearn.model_selection import GridSearchCV
#msvr = MSVR(kernel = 'rbf', gamma = 10, epsilon = 0.01, tol=0.01, C=100)
msvr = MSVR(kernel = 'rbf', gamma = 20, epsilon = 0.01, tol=0.01, C=100)
msvr.fit(X_train_norm, y_train_norm)
y_pred = msvr.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.067
# Mean Absolute Error: 0.202
# R2 Score: 0.253
# Explained Variance Score: 0.253

# %%
# convert normalized data back into original data
y_data = yMMS.inverse_transform(y_norm)
y_data_pred = yMMS.inverse_transform(y_pred)

plt.figure()
s = 25
plt.scatter(y_data[:, 0], y_data[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_data_pred[:, 0], y_data_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Multi-Output Support Vector Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Optimal Parameter Search for Multi-Layer Perceptron

# %%
big = []
lb = 101 # lower bound
ub = 111 # upper bound
for i in range(lb, ub):
    for j in range(lb, ub):
        for k in range(lb, ub):
            big.append([i,j,k])

# %%
# Nerual Network
# Finding hyperparameters
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

param_grid = {
    'hidden_layer_sizes': big,
    'activation': ['relu'],  
    'solver': ['adam'],
    'alpha': [0.001],
    'random_state': [42],
    'max_iter': [50000],
    'learning_rate_init': [0.01],
    'batch_size': [100],
    'tol': [1e-6]
}

kf = KFold(n_splits=5, shuffle=False)
regr = MLPRegressor()
neuralNetwork = GridSearchCV(estimator=regr, param_grid=param_grid, cv=kf, n_jobs=-1, scoring='r2')

neuralNetwork.fit(X_train_norm, y_train_norm)

best_params = neuralNetwork.best_params_
best_score = neuralNetwork.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'activation': 'relu', 'alpha': 0.001, 'batch_size': 100, 'hidden_layer_sizes': [107, 107, 109], 'learning_rate_init': 0.01, 'max_iter': 50000, 'random_state': 42, 'solver': 'adam', 'tol': 1e-06}
# Best Score: 0.21801677325304536

# %% [markdown]
# ### Best Parameter Combinations

# %% [raw]
# Best layer sizes for normalized input values:
# 'hidden_layer_sizes': [9, 10, 8] # 0.1607781218255218
# 'hidden_layer_sizes': [14, 13, 11] # 0.2070020983902056
# 'hidden_layer_sizes': [26, 26, 29] # 0.22067490979234602
# 'hidden_layer_sizes': [31, 36, 36] # 0.22034390237673934
# 'hidden_layer_sizes': [45, 50, 50] # 0.21867448049243374
# 'hidden_layer_sizes': [51, 57, 59] # 0.22761504948587077
# 'hidden_layer_sizes': [69, 69, 64] # 0.22113695222157906
# 'hidden_layer_sizes': [79, 71, 73] # 0.2164447856092865
# 'hidden_layer_sizes': [83, 89, 87] # 0.21941214234138418
# 'hidden_layer_sizes': [94, 100, 99] # 0.22929478725425398
# 'hidden_layer_sizes': [107, 107, 109] # 0.21801677325304536

# %% [markdown]
# ### Multi-Layer Perceptron Regression

# %%
from sklearn.neural_network import MLPRegressor

settings = {
    'activation': 'relu', 
    'alpha': 0.001, 
    'batch_size': 100, 
    'hidden_layer_sizes': [94, 100, 99], 
    'learning_rate_init': 0.01, 
    'max_iter': 50000, 
    'random_state': 42, 
    'solver': 'adam', 
    'tol': 1e-6
}
mlp = MLPRegressor(**settings)
mlp.fit(X_train_norm, y_train_norm)
y_pred = mlp.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.074
# Mean Absolute Error: 0.225
# R2 Score: 0.163
# Explained Variance Score: 0.164

# %%
# convert normalized data back into original data
y_data = yMMS.inverse_transform(y_norm)
y_data_pred = yMMS.inverse_transform(y_pred)

plt.figure()
s = 25
plt.scatter(y_data[:, 0], y_data[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_data_pred[:, 0], y_data_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("MLP Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Neural Network Using PyTorch

# %%
import torch
import torch.nn as nn
 
# Define the model
model = nn.Sequential(
    nn.Linear(3, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 2)
)

# %%
import torch.optim as optim
 
# loss function and optimizer
loss_fn = nn.L1Loss()  # MAE
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
import tqdm
import copy
X_train_torch = torch.tensor(X_train_norm, dtype=torch.float32)
y_train_torch = torch.tensor(y_train_norm, dtype=torch.float32)
X_test_torch = torch.tensor(X_test_norm, dtype=torch.float32)
y_test_torch = torch.tensor(y_test_norm, dtype=torch.float32)

# training parameters
n_epochs = 100   # number of epochs to run
batch_size = 10  # size of each batch
batch_start = torch.arange(0, len(X_train_torch), batch_size)

# Hold the best model
best_loss = np.inf   # init to infinity
best_weights = None
history = []

# training loop
for epoch in range(n_epochs):
    model.train()
    with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
        bar.set_description(f"Epoch {epoch}")
        for start in bar:
            # take a batch
            X_batch = X_train_torch[start:start+batch_size]
            y_batch = y_train_torch[start:start+batch_size]
            # forward pass
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            # update weights
            optimizer.step()
            # print progress
            bar.set_postfix(loss=float(loss))
    # evaluate accuracy at end of each epoch
    model.eval()
    y_pred = model(X_test_torch)
    loss = loss_fn(y_pred, y_test_torch)
    loss = float(loss)
    history.append(loss)
    if loss < best_loss:
        best_loss = loss
        best_weights = copy.deepcopy(model.state_dict())

# restore model and return best accuracy
model.load_state_dict(best_weights)
# Out:
# <All keys matched successfully>

# %%
print("Loss: %.2f" % np.sqrt(best_loss))
plt.plot(history)
plt.show()
# Out:
# Loss: 0.46

# %%
y_pred = model(X_test_torch).detach().numpy()
metrics(y_test_norm, y_pred)
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
#plt.xlim(25.6252, 25.62532)
#plt.ylim(-80.42014,-80.42004)
#plt.xlim(25.6, 25.65)
#plt.ylim(-80.5,-80.4)
plt.xlabel("Latitude (Normalized)")
plt.ylabel("Longitude (Normalized)")
plt.title("Neural Network")
plt.legend(loc="best")
plt.show()
# Out:
# Mean Squared Error: 0.077
# Mean Absolute Error: 0.212
# R2 Score: 0.139
# Explained Variance Score: 0.159

# %% [markdown]
# ### Deep Learning using Keras

# %%
# Deep learning
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from matplotlib import pyplot

# define model
model = Sequential()
model.add(Dense(25, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(2, activation='linear'))
opt = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
# fit model
history = model.fit(X_train_norm, y_train_norm, validation_data=(X_test_norm, y_test_norm), epochs=100)
# evaluate the model
_, train_mse = model.evaluate(X_train_norm, y_train_norm, verbose=0)
_, test_mse = model.evaluate(X_test_norm, y_test_norm, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_mse, test_mse))
# Out:
# Epoch 1/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3962 - mse: 0.3962 - val_loss: 0.0915 - val_mse: 0.0915
# Epoch 2/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0907 - mse: 0.0907 - val_loss: 0.0891 - val_mse: 0.0891
# Epoch 3/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0895 - mse: 0.0895 - val_loss: 0.0866 - val_mse: 0.0866
# Epoch 4/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0894 - mse: 0.0894 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 5/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0901 - mse: 0.0901 - val_loss: 0.0856 - val_mse: 0.0856
# Epoch 6/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0880 - mse: 0.0880 - val_loss: 0.0861 - val_mse: 0.0861
# Epoch 7/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0889 - mse: 0.0889 - val_loss: 0.0850 - val_mse: 0.0850
# Epoch 8/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0868 - mse: 0.0868 - val_loss: 0.0856 - val_mse: 0.0856
# Epoch 9/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0840 - val_mse: 0.0840
# Epoch 10/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0846 - val_mse: 0.0846
# Epoch 11/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.0870 - val_mse: 0.0870
# Epoch 12/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.0863 - val_mse: 0.0863
# Epoch 13/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0856 - mse: 0.0856 - val_loss: 0.0841 - val_mse: 0.0841
# Epoch 14/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 15/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0835 - val_mse: 0.0835
# Epoch 16/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0836 - mse: 0.0836 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 17/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0839 - mse: 0.0839 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 18/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.0824 - val_mse: 0.0824
# Epoch 19/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.0825 - val_mse: 0.0825
# Epoch 20/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0836 - mse: 0.0836 - val_loss: 0.0858 - val_mse: 0.0858
# Epoch 21/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0838 - mse: 0.0838 - val_loss: 0.0832 - val_mse: 0.0832
# Epoch 22/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 23/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0808 - mse: 0.0808 - val_loss: 0.0833 - val_mse: 0.0833
# Epoch 24/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0828 - mse: 0.0828 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 25/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0813 - mse: 0.0813 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 26/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 27/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0816 - val_mse: 0.0816
# Epoch 28/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0815 - mse: 0.0815 - val_loss: 0.0819 - val_mse: 0.0819
# Epoch 29/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.0811 - val_mse: 0.0811
# Epoch 30/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0815 - mse: 0.0815 - val_loss: 0.0835 - val_mse: 0.0835
# Epoch 31/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.0811 - val_mse: 0.0811
# Epoch 32/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0824 - mse: 0.0824 - val_loss: 0.0829 - val_mse: 0.0829
# Epoch 33/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 34/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0819 - mse: 0.0819 - val_loss: 0.0823 - val_mse: 0.0823
# Epoch 35/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0811 - mse: 0.0811 - val_loss: 0.0815 - val_mse: 0.0815
# Epoch 36/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 37/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.0811 - val_mse: 0.0811
# Epoch 38/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0831 - mse: 0.0831 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 39/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0807 - mse: 0.0807 - val_loss: 0.0819 - val_mse: 0.0819
# Epoch 40/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 41/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0849 - mse: 0.0849 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 42/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.0801 - val_mse: 0.0801
# Epoch 43/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0791 - mse: 0.0791 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 44/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 45/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0838 - val_mse: 0.0838
# Epoch 46/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0831 - mse: 0.0831 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 47/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0824 - mse: 0.0824 - val_loss: 0.0841 - val_mse: 0.0841
# Epoch 48/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.0822 - val_mse: 0.0822
# Epoch 49/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 50/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 51/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0815 - mse: 0.0815 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 52/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0797 - val_mse: 0.0797
# Epoch 53/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0793 - mse: 0.0793 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 54/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 55/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0797 - mse: 0.0797 - val_loss: 0.0802 - val_mse: 0.0802
# Epoch 56/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0805 - mse: 0.0805 - val_loss: 0.0797 - val_mse: 0.0797
# Epoch 57/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0805 - mse: 0.0805 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 58/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0822 - val_mse: 0.0822
# Epoch 59/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.0798 - val_mse: 0.0798
# Epoch 60/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0797 - val_mse: 0.0797
# Epoch 61/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 62/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0798 - mse: 0.0798 - val_loss: 0.0794 - val_mse: 0.0794
# Epoch 63/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0801 - mse: 0.0801 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 64/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0803 - mse: 0.0803 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 65/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0813 - mse: 0.0813 - val_loss: 0.0799 - val_mse: 0.0799
# Epoch 66/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.0794 - val_mse: 0.0794
# Epoch 67/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 68/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 69/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0798 - mse: 0.0798 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 70/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 71/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0789 - mse: 0.0789 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 72/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 73/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0793 - mse: 0.0793 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 74/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0780 - mse: 0.0780 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 75/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0791 - mse: 0.0791 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 76/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0803 - mse: 0.0803 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 77/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0788 - mse: 0.0788 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 78/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0797 - mse: 0.0797 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 79/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0786 - val_mse: 0.0786
# Epoch 80/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0789 - mse: 0.0789 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 81/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 82/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0785 - mse: 0.0785 - val_loss: 0.0793 - val_mse: 0.0793
# Epoch 83/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0778 - mse: 0.0778 - val_loss: 0.0797 - val_mse: 0.0797
# Epoch 84/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.0795 - val_mse: 0.0795
# Epoch 85/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.0787 - val_mse: 0.0787
# Epoch 86/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0786 - mse: 0.0786 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 87/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0788 - mse: 0.0788 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 88/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0816 - mse: 0.0816 - val_loss: 0.0785 - val_mse: 0.0785
# Epoch 89/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0784 - mse: 0.0784 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 90/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 91/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0784 - mse: 0.0784 - val_loss: 0.0786 - val_mse: 0.0786
# Epoch 92/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.0829 - val_mse: 0.0829
# Epoch 93/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0796 - mse: 0.0796 - val_loss: 0.0802 - val_mse: 0.0802
# Epoch 94/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0806 - mse: 0.0806 - val_loss: 0.0791 - val_mse: 0.0791
# Epoch 95/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0789 - mse: 0.0789 - val_loss: 0.0798 - val_mse: 0.0798
# Epoch 96/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.0787 - val_mse: 0.0787
# Epoch 97/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0811 - mse: 0.0811 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 98/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0779 - mse: 0.0779 - val_loss: 0.0822 - val_mse: 0.0822
# Epoch 99/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.0791 - val_mse: 0.0791
# Epoch 100/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0792 - mse: 0.0792 - val_loss: 0.0783 - val_mse: 0.0783
# Train: 0.078, Test: 0.078

# %%
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot mse during training
pyplot.subplot(212)
pyplot.tight_layout()
pyplot.title('Mean Squared Error')
pyplot.plot(history.history['mse'], label='train')
pyplot.plot(history.history['val_mse'], label='test')
pyplot.legend()
pyplot.show()

# %%
y_pred = model(X_test_norm)
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Latitude (Normalized)")
plt.ylabel("Longitude (Normalized)")
plt.title("Deep Learning")
plt.legend(loc="best")
plt.show()
