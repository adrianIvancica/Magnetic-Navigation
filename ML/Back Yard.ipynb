# %% [markdown]
# ### Data Set Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Use data collected from a back yard at a +/- 8 Gauss resolution on 4/1/24
# The actual data set is not provided as it contains exact latitude and longitute coordinates of a person's home
G8_4124 = pd.read_csv("magMapCapture8G_4_1_24.txt", sep=',')

# %%
# convert text file data into modifyable types compatible with pandas data structures
# convert string data to numeric data
col = ['X','Y','Z','Azimuth','Bearing','Latitude','Longitude','Altitude']
G8_4124[col] = G8_4124[col].apply(pd.to_numeric)
# convert date string to date object
col = ['Date']
G8_4124[col] = G8_4124[col].apply(lambda x: pd.to_datetime(x, format='%m/%d/%Y'))
# convert date string to date object
col = ['Time']
G8_4124[col] = G8_4124[col].apply(lambda x: pd.to_datetime(x, format='%H:%M:%S').dt.time)

# %%
# Functions used to convert raw digital data to nano Tesla
def convert_raw_to_mG(x, mode):
    if mode == 1: # assumes 2G/12000LSB ~ 0.167mG/LSB
        return 2/12000 * x
    else: # assumes 8G/3000LSB ~ 2.67mG/LSB 
        return 8/3000 * x
def convert_mG_to_nT(x):
    return 100 * x
def convert_raw_to_nT(x, mode):
    mg = convert_raw_to_mG(x, mode)
    return convert_mG_to_nT(mg)

# %%
# convert raw data to nT
col = ['X','Y','Z']
G8_4124[col] = G8_4124[col].apply(lambda x: round(convert_raw_to_nT(x, 0),1))

# %%
# Orientation: X = East, Y = North, Z = Straight Up
filter = (G8_4124['Direction'] == 'E') | (G8_4124['Direction'] == 'ESE') | (G8_4124['Direction'] == 'ENE')

# Latitude and Longitude (targets)
y = G8_4124.loc[filter, ['Longitude','Latitude']].values 

# X, Y, Z magnetic readings (features)
X = G8_4124.loc[filter, ['X','Y','Z']].values

# %% [markdown]
# ### Data Split Creation

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Scaled
XSS = StandardScaler()
XSS.fit(X)
X_scaled = XSS.transform(X)

ySS = StandardScaler()
ySS.fit(y)
y_scaled = ySS.transform(y)

# Normalized
XMMS = MinMaxScaler()
X_norm = XMMS.fit_transform(X)

yMMS = MinMaxScaler()
y_norm = yMMS.fit_transform(y)

# %%
# Standard Split
# Split data into a training set (70%) and a testing set (30%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1)

# Scaled Split
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(
    X_scaled, y_scaled, test_size=0.3, random_state=1)

# Normalized Split
X_train_norm, X_test_norm, y_train_norm, y_test_norm = train_test_split(
    X_norm, y_norm, test_size=0.3, random_state=1)

# %% [markdown]
# ### Defining Metrics

# %%
from sklearn.metrics import  mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

def metrics(test, pred):
    mse = mean_squared_error(test, pred)
    print(f'Mean Squared Error: {mse:.3f}')
    
    mae = mean_absolute_error(test, pred)
    print(f'Mean Absolute Error: {mae:.3f}')
    
    r2 = r2_score(test, pred)
    print(f'R2 Score: {r2:.3f}')
    
    evs = explained_variance_score(test, pred)
    print(f'Explained Variance Score: {evs:.3f}')

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# Define parameter grid
param_grid = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
    'max_depth': range(3, 11),
    'min_samples_leaf': range(3, 11)
}

# Create DecisionTreeRegressor instance
tree = DecisionTreeRegressor(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=tree, param_grid=param_grid, cv=10, n_jobs=-1, verbose=1)

# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 10 folds for each of 192 candidates, totalling 1920 fits
# Best Parameters: {'criterion': 'squared_error', 'max_depth': 7, 'min_samples_leaf': 4}
# Best Score: 0.5767940795317341

# %%
best_tree = DecisionTreeRegressor(criterion=best_params.get('criterion'),
                                         max_depth=best_params.get('max_depth'),
                                         min_samples_leaf=best_params.get('min_samples_leaf'),
                                         random_state=42)
best_tree.fit(X_train_norm, y_train_norm)
y_pred = best_tree.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.032
# Mean Absolute Error: 0.120
# R2 Score: 0.567
# Explained Variance Score: 0.568

# %%
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Longitude (Normalized)")
plt.ylabel("Latitude (Normalized)")
plt.title("Decision Tree Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 150, 200],  # Number of trees in the forest
    'max_depth': range(1, 16),
    'min_samples_leaf': range(1, 6),
}

# Create RandomForestRegressor instance
rf_model = RandomForestRegressor(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=10, n_jobs=-1, verbose=1)

# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# Best Score: 0.6818630290321992

# %%
settings = {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 150}
mlp = RandomForestRegressor(**settings)
mlp.fit(X_train_norm, y_train_norm)
y_pred = mlp.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.025
# Mean Absolute Error: 0.105
# R2 Score: 0.656
# Explained Variance Score: 0.658

# %%
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Longitude (Normalized)")
plt.ylabel("Latitude (Normalized)")
plt.title("Random Forest Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Multi-Output Support Vector Regression

# %%
# MSVR needs data to be in the range -1 to 1 (normalized) in order to function properly
import sys
sys.path.append('./msvr-master/msvr-master')
from model.MSVR import MSVR
from model.utility import rmse
#msvr = MSVR(kernel = 'rbf', gamma = 10, epsilon = 0.01, tol=0.01, C=100)
msvr = MSVR(kernel = 'rbf', gamma = 20, epsilon = 0.01, tol=0.01, C=100)
msvr.fit(X_train_norm, y_train_norm)
y_pred = msvr.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.027
# Mean Absolute Error: 0.117
# R2 Score: 0.638
# Explained Variance Score: 0.638

# %%
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Longitude (Normalized)")
plt.ylabel("Latitude (Normalized)")
plt.title("Multi-Output Support Vector Regression")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Optimal Parameter Search for Multi-Layer Perceptron

# %%
big = []
for i in range(21,41):
    for j in range(21, 41):
        for k in range(21, 41):
            big.append([i,j,k])

# %%
# Nerual Network
# Finding hyperparameters
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

param_grid = {
    'hidden_layer_sizes': big,
    'activation': ['relu'],  
    'solver': ['adam'],
    'alpha': [0.001],
    'random_state': [42],
    'max_iter': [50000],
    'learning_rate_init': [0.01],
    'batch_size': [100],
    'tol': [1e-6]
}

kf = KFold(n_splits=5, shuffle=False)
regr = MLPRegressor()
neuralNetwork = GridSearchCV(estimator=regr, param_grid=param_grid, cv=kf, n_jobs=-1, verbose=1, scoring='r2')

neuralNetwork.fit(X_train_norm, y_train_norm)
# Out:
# Fitting 5 folds for each of 8000 candidates, totalling 40000 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=MLPRegressor(), n_jobs=-1,
#              param_grid={'activation': ['relu'], 'alpha': [0.001],
#                          'batch_size': [100],
#                          'hidden_layer_sizes': [[21, 21, 21], [21, 21, 22],
#                                                 [21, 21, 23], [21, 21, 24],
#                                                 [21, 21, 25], [21, 21, 26],
#                                                 [21, 21, 27], [21, 21, 28],
#                                                 [21, 21, 29], [21, 21, 30],
#                                                 [21, 21, 31], [21, 21, 32],
#                                                 [21, 21, 33], [21, 21, 34],
#                                                 [21, 21, 35], [21, 21, 36],
#                                                 [21, 21, 37], [21, 21, 38],
#                                                 [21, 21, 39], [21, 21, 40],
#                                                 [21, 22, 21], [21, 22, 22],
#                                                 [21, 22, 23], [21, 22, 24],
#                                                 [21, 22, 25], [21, 22, 26],
#                                                 [21, 22, 27], [21, 22, 28],
#                                                 [21, 22, 29], [21, 22, 30], ...],
#                          'learning_rate_init': [0.01], 'max_iter': [50000],
#                          'random_state': [42], 'solver': ['adam'],
#                          'tol': [1e-06]},
#              scoring='r2', verbose=1)

# %%
best_params = neuralNetwork.best_params_
best_score = neuralNetwork.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'activation': 'relu', 'alpha': 0.001, 'batch_size': 100, 'hidden_layer_sizes': [29, 35, 38], 'learning_rate_init': 0.01, 'max_iter': 50000, 'random_state': 42, 'solver': 'adam', 'tol': 1e-06}
# Best Score: 0.6618413373815811

# %% [markdown]
# ### Best Parameter Combinations

# %% [raw]
# Best layer sizes for original input values:
# 'hidden_layer_sizes': [15, 16, 14] # 0.6383587587287147
# 'hidden_layer_sizes': [32, 33, 35] # 0.6548524401590061
# 'hidden_layer_sizes': [29, 35, 38] # 0.6618413373815811
# 'hidden_layer_sizes': [53, 52, 53] # 0.6613618024705756
# 'hidden_layer_sizes': [78, 71, 71] # 0.6580926781121506
# 'hidden_layer_sizes': [89, 87, 87] # 0.6599918326677473

# %% [markdown]
# ### Multi-Layer Perceptron Regression

# %%
from sklearn.neural_network import MLPRegressor

settings = {
    'activation': 'relu', 
    'alpha': 0.001, 
    'batch_size': 100, 
    'hidden_layer_sizes': [29, 35, 38], 
    'learning_rate_init': 0.01, 
    'max_iter': 50000, 
    'random_state': 42, 
    'solver': 'adam', 
    'tol': 1e-6
}
mlp = MLPRegressor(**settings)
mlp.fit(X_train_norm, y_train_norm)
y_pred = mlp.predict(X_test_norm)
metrics(y_test_norm, y_pred)
# Out:
# Mean Squared Error: 0.029
# Mean Absolute Error: 0.123
# R2 Score: 0.613
# Explained Variance Score: 0.617

# %%
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Longitude (Normalized)")
plt.ylabel("Latitude (Normalized)")
plt.title("MLP Regresson")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Neural Network using PyTorch

# %%
import torch
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
import torch.nn as nn

# %%
# Define the model
model = nn.Sequential(
    nn.Linear(3, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 100),
    nn.ReLU(),
    nn.Linear(100, 2)
)

# %%
import torch.optim as optim
 
# loss function and optimizer
loss_fn = nn.L1Loss()  # MAE
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
import tqdm
import copy
X_train_torch = torch.tensor(X_train_norm, dtype=torch.float32)
y_train_torch = torch.tensor(y_train_norm, dtype=torch.float32)
X_test_torch = torch.tensor(X_test_norm, dtype=torch.float32)
y_test_torch = torch.tensor(y_test_norm, dtype=torch.float32)

# training parameters
n_epochs = 100   # number of epochs to run
batch_size = 10  # size of each batch
batch_start = torch.arange(0, len(X_train_torch), batch_size)

# Hold the best model
best_loss = np.inf   # init to infinity
best_weights = None
history = []

# training loop
for epoch in range(n_epochs):
    model.train()
    with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
        bar.set_description(f"Epoch {epoch}")
        for start in bar:
            # take a batch
            X_batch = X_train_torch[start:start+batch_size]
            y_batch = y_train_torch[start:start+batch_size]
            # forward pass
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            # update weights
            optimizer.step()
            # print progress
            bar.set_postfix(loss=float(loss))
    # evaluate accuracy at end of each epoch
    model.eval()
    y_pred = model(X_test_torch)
    loss = loss_fn(y_pred, y_test_torch)
    loss = float(loss)
    history.append(loss)
    if loss < best_loss:
        best_loss = loss
        best_weights = copy.deepcopy(model.state_dict())

# restore model and return best accuracy
model.load_state_dict(best_weights)
# Out:
# <All keys matched successfully>

# %%
print("Loss: %.2f" % np.sqrt(best_loss))
plt.plot(history)
plt.show()
# Out:
# Loss: 0.37

# %%
y_pred = model(X_test_torch).detach().numpy()
metrics(y_test_norm, y_pred)
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
#plt.xlim(25.6252, 25.62532)
#plt.ylim(-80.42014,-80.42004)
#plt.xlim(25.6, 25.65)
#plt.ylim(-80.5,-80.4)
plt.xlabel("Latitude (Normalized)")
plt.ylabel("Longitude (Normalized)")
plt.title("Neural Network")
plt.legend(loc="best")
plt.show()
# Out:
# Mean Squared Error: 0.033
# Mean Absolute Error: 0.136
# R2 Score: 0.565
# Explained Variance Score: 0.581

# %% [markdown]
# ### Deep Learning using Keras

# %%
# Deep learning
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from matplotlib import pyplot

# define model
model = Sequential()
model.add(Dense(25, input_dim=3, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(2, activation='linear'))
opt = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
# fit model
history = model.fit(X_train_norm, y_train_norm, validation_data=(X_test_norm, y_test_norm), epochs=100)
# evaluate the model
_, train_mse = model.evaluate(X_train_norm, y_train_norm, verbose=0)
_, test_mse = model.evaluate(X_test_norm, y_test_norm, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_mse, test_mse))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4086 - mse: 0.4086 - val_loss: 0.1203 - val_mse: 0.1203
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1009 - mse: 0.1009 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0890 - mse: 0.0890 - val_loss: 0.0764 - val_mse: 0.0764
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0784 - mse: 0.0784 - val_loss: 0.0717 - val_mse: 0.0717
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0757 - mse: 0.0757 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0719 - mse: 0.0719 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723 - mse: 0.0723 - val_loss: 0.0722 - val_mse: 0.0722
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0813 - mse: 0.0813 - val_loss: 0.0652 - val_mse: 0.0652
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0772 - mse: 0.0772 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0731 - mse: 0.0731 - val_loss: 0.0645 - val_mse: 0.0645
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0712 - mse: 0.0712 - val_loss: 0.0671 - val_mse: 0.0671
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0686 - mse: 0.0686 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0693 - mse: 0.0693 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0706 - mse: 0.0706 - val_loss: 0.0612 - val_mse: 0.0612
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0664 - mse: 0.0664 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0651 - mse: 0.0651 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0626 - val_mse: 0.0626
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0658 - mse: 0.0658 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0649 - val_mse: 0.0649
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0717 - mse: 0.0717 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0681 - mse: 0.0681 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673 - mse: 0.0673 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671 - mse: 0.0671 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0661 - mse: 0.0661 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0719 - mse: 0.0719 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0665 - mse: 0.0665 - val_loss: 0.0572 - val_mse: 0.0572
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0574 - val_mse: 0.0574
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0652 - mse: 0.0652 - val_loss: 0.0568 - val_mse: 0.0568
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0565 - val_mse: 0.0565
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0571 - val_mse: 0.0571
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577 - mse: 0.0577 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0560 - val_mse: 0.0560
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0572 - mse: 0.0572 - val_loss: 0.0560 - val_mse: 0.0560
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0556 - val_mse: 0.0556
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0560 - val_mse: 0.0560
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579 - mse: 0.0579 - val_loss: 0.0559 - val_mse: 0.0559
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0581 - mse: 0.0581 - val_loss: 0.0554 - val_mse: 0.0554
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0573 - mse: 0.0573 - val_loss: 0.0562 - val_mse: 0.0562
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0563 - mse: 0.0563 - val_loss: 0.0550 - val_mse: 0.0550
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0565 - val_mse: 0.0565
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0558 - val_mse: 0.0558
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0561 - val_mse: 0.0561
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0556 - val_mse: 0.0556
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0563 - mse: 0.0563 - val_loss: 0.0546 - val_mse: 0.0546
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0563 - mse: 0.0563 - val_loss: 0.0626 - val_mse: 0.0626
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0552 - val_mse: 0.0552
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0575 - mse: 0.0575 - val_loss: 0.0555 - val_mse: 0.0555
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0555 - mse: 0.0555 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0555 - val_mse: 0.0555
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0557 - mse: 0.0557 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0515 - mse: 0.0515 - val_loss: 0.0670 - val_mse: 0.0670
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0690 - mse: 0.0690 - val_loss: 0.0541 - val_mse: 0.0541
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0543 - mse: 0.0543 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0538 - mse: 0.0538 - val_loss: 0.0550 - val_mse: 0.0550
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0605 - mse: 0.0605 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0533 - val_mse: 0.0533
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0552 - mse: 0.0552 - val_loss: 0.0539 - val_mse: 0.0539
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577 - mse: 0.0577 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0539 - mse: 0.0539 - val_loss: 0.0540 - val_mse: 0.0540
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0532 - mse: 0.0532 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0536 - val_mse: 0.0536
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0522 - mse: 0.0522 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0512 - mse: 0.0512 - val_loss: 0.0528 - val_mse: 0.0528
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0522 - mse: 0.0522 - val_loss: 0.0549 - val_mse: 0.0549
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0538 - mse: 0.0538 - val_loss: 0.0535 - val_mse: 0.0535
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0506 - mse: 0.0506 - val_loss: 0.0532 - val_mse: 0.0532
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0573 - val_mse: 0.0573
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0567 - val_mse: 0.0567
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0524 - val_mse: 0.0524
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0540 - mse: 0.0540 - val_loss: 0.0525 - val_mse: 0.0525
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0542 - mse: 0.0542 - val_loss: 0.0544 - val_mse: 0.0544
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0548 - mse: 0.0548 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0548 - val_mse: 0.0548
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0534 - mse: 0.0534 - val_loss: 0.0523 - val_mse: 0.0523
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0526 - mse: 0.0526 - val_loss: 0.0521 - val_mse: 0.0521
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0525 - mse: 0.0525 - val_loss: 0.0525 - val_mse: 0.0525
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0520 - val_mse: 0.0520
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0548 - mse: 0.0548 - val_loss: 0.0518 - val_mse: 0.0518
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0605 - mse: 0.0605 - val_loss: 0.0510 - val_mse: 0.0510
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0557 - mse: 0.0557 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0550 - mse: 0.0550 - val_loss: 0.0520 - val_mse: 0.0520
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - mse: 0.0509 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0528 - mse: 0.0528 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0520 - mse: 0.0520 - val_loss: 0.0508 - val_mse: 0.0508
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.0514 - val_mse: 0.0514
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0546 - mse: 0.0546 - val_loss: 0.0512 - val_mse: 0.0512
# Train: 0.051, Test: 0.051

# %%
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot mse during training
pyplot.subplot(212)
pyplot.tight_layout()
pyplot.title('Mean Squared Error')
pyplot.plot(history.history['mse'], label='train')
pyplot.plot(history.history['val_mse'], label='test')
pyplot.legend()
pyplot.show()

# %%
y_pred = model(X_test_norm)
plt.figure()
s = 25
plt.scatter(y_norm[:, 0], y_norm[:, 1], c="navy", s=s, edgecolor="black", label="Data")
plt.scatter(y_pred[:, 0], y_pred[:, 1], color="orange", s=s, edgecolor="black", label="Prediction")
plt.xlabel("Latitude (Normalized)")
plt.ylabel("Longitude (Normalized)")
plt.title("Deep Learning")
plt.legend(loc="best")
plt.show()
